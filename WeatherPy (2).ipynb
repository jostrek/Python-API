# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import os

# Import API key
#import api_keys
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file= "output_data/cities.csv"
    
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 593

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# set up additional columns to hold information
lats=[]
lngs=[]
city_names=[]
cloudiness=[]
countries=[]
dates=[]
humidity=[]
max_temp=[]
speed=[]

record_no=0
set_no =0
# Save config information
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "metric"
#building query url
query_url = f"{url}appid={api_key}&units={units}&q="
response = requests.get(query_url + "Los Angeles").json()
response
for city in cities:
    print(f"Processing Record {record_no} of Set {set_no} | {city}")
    record_no+=1
    if record_no%50==0:
        set_no +=1
        record_no =0
    try:
        response = requests.get(query_url + city).json()
        city_names.append(response['name'])
        lats.append(response['coord']['lat'])
        lngs.append(response['coord']['lon'])
        cloudiness.append(response['clouds']['all'])
        countries.append(response['sys']['country'])
        dates.append(response['dt'])
        humidity.append(response['main']['humidity'])
        max_temp.append(response['main']['temp_max'])
        speed.append(response['wind']['speed'])
    except KeyError:
        print("City not found. Skipping...")
print("-----------------------------\nData Retrieval Complete\n-----------------------------")
# Out:
# Processing Record 0 of Set 0 | karratha
# Processing Record 1 of Set 0 | halden
# Processing Record 2 of Set 0 | jamestown
# Processing Record 3 of Set 0 | ilhabela
# Processing Record 4 of Set 0 | tumannyy
# City not found. Skipping...
# Processing Record 5 of Set 0 | castro
# Processing Record 6 of Set 0 | urfa
# City not found. Skipping...
# Processing Record 7 of Set 0 | punta arenas
# Processing Record 8 of Set 0 | wewak
# Processing Record 9 of Set 0 | port augusta
# Processing Record 10 of Set 0 | rodino
# Processing Record 11 of Set 0 | dingle
# Processing Record 12 of Set 0 | ushuaia
# Processing Record 13 of Set 0 | celestun
# Processing Record 14 of Set 0 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 0 | rafaela
# Processing Record 16 of Set 0 | saskylakh
# Processing Record 17 of Set 0 | naugarzan
# City not found. Skipping...
# Processing Record 18 of Set 0 | riobamba
# Processing Record 19 of Set 0 | kavaratti
# Processing Record 20 of Set 0 | wasilla
# Processing Record 21 of Set 0 | nuevo casas grandes
# Processing Record 22 of Set 0 | khatanga
# Processing Record 23 of Set 0 | le port
# Processing Record 24 of Set 0 | aklavik
# Processing Record 25 of Set 0 | cape town
# Processing Record 26 of Set 0 | upernavik
# Processing Record 27 of Set 0 | tiksi
# Processing Record 28 of Set 0 | camacupa
# Processing Record 29 of Set 0 | caravelas
# Processing Record 30 of Set 0 | bredasdorp
# Processing Record 31 of Set 0 | santiago
# Processing Record 32 of Set 0 | bluff
# Processing Record 33 of Set 0 | vao
# Processing Record 34 of Set 0 | neuruppin
# Processing Record 35 of Set 0 | gat
# Processing Record 36 of Set 0 | mar del plata
# Processing Record 37 of Set 0 | isangel
# Processing Record 38 of Set 0 | lazaro cardenas
# Processing Record 39 of Set 0 | yali
# Processing Record 40 of Set 0 | rikitea
# Processing Record 41 of Set 0 | cidreira
# Processing Record 42 of Set 0 | college
# Processing Record 43 of Set 0 | manado
# Processing Record 44 of Set 0 | palana
# Processing Record 45 of Set 0 | itoman
# Processing Record 46 of Set 0 | mys shmidta
# City not found. Skipping...
# Processing Record 47 of Set 0 | nikolskoye
# Processing Record 48 of Set 0 | coquimbo
# Processing Record 49 of Set 0 | praia da vitoria
# Processing Record 0 of Set 1 | vaini
# Processing Record 1 of Set 1 | sao joao da barra
# Processing Record 2 of Set 1 | kieta
# Processing Record 3 of Set 1 | bartica
# Processing Record 4 of Set 1 | rocha
# Processing Record 5 of Set 1 | vila velha
# Processing Record 6 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 7 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 8 of Set 1 | ponta do sol
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | richards bay
# Processing Record 11 of Set 1 | dikson
# Processing Record 12 of Set 1 | katsuura
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | sungaipenuh
# Processing Record 15 of Set 1 | mataura
# Processing Record 16 of Set 1 | mad
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | sitka
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 1 | limoux
# Processing Record 23 of Set 1 | kaitangata
# Processing Record 24 of Set 1 | severo-kurilsk
# Processing Record 25 of Set 1 | amapa
# Processing Record 26 of Set 1 | yar-sale
# Processing Record 27 of Set 1 | villa union
# Processing Record 28 of Set 1 | thompson
# Processing Record 29 of Set 1 | gaya
# Processing Record 30 of Set 1 | ferme-neuve
# Processing Record 31 of Set 1 | rawson
# Processing Record 32 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 33 of Set 1 | hami
# Processing Record 34 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 35 of Set 1 | anadyr
# Processing Record 36 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 1 | suba
# Processing Record 38 of Set 1 | yongan
# Processing Record 39 of Set 1 | pombia
# Processing Record 40 of Set 1 | mizdah
# Processing Record 41 of Set 1 | deputatskiy
# Processing Record 42 of Set 1 | carnarvon
# Processing Record 43 of Set 1 | te anau
# Processing Record 44 of Set 1 | puerto el triunfo
# Processing Record 45 of Set 1 | arraial do cabo
# Processing Record 46 of Set 1 | tabiauea
# City not found. Skipping...
# Processing Record 47 of Set 1 | tasiilaq
# Processing Record 48 of Set 1 | ginir
# Processing Record 49 of Set 1 | saint-philippe
# Processing Record 0 of Set 2 | lagoa
# Processing Record 1 of Set 2 | port lincoln
# Processing Record 2 of Set 2 | kodiak
# Processing Record 3 of Set 2 | talgar
# Processing Record 4 of Set 2 | okha
# Processing Record 5 of Set 2 | hambantota
# Processing Record 6 of Set 2 | busselton
# Processing Record 7 of Set 2 | hermanus
# Processing Record 8 of Set 2 | keti bandar
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | fortuna
# Processing Record 11 of Set 2 | bonavista
# Processing Record 12 of Set 2 | puerto ayora
# Processing Record 13 of Set 2 | provideniya
# Processing Record 14 of Set 2 | hokitika
# Processing Record 15 of Set 2 | koygorodok
# Processing Record 16 of Set 2 | ballina
# Processing Record 17 of Set 2 | margate
# Processing Record 18 of Set 2 | ribeira grande
# Processing Record 19 of Set 2 | port elizabeth
# Processing Record 20 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 21 of Set 2 | yellowknife
# Processing Record 22 of Set 2 | morondava
# Processing Record 23 of Set 2 | avarua
# Processing Record 24 of Set 2 | mehamn
# Processing Record 25 of Set 2 | port alfred
# Processing Record 26 of Set 2 | taoudenni
# Processing Record 27 of Set 2 | castanos
# Processing Record 28 of Set 2 | segovia
# Processing Record 29 of Set 2 | covington
# Processing Record 30 of Set 2 | vanavara
# Processing Record 31 of Set 2 | zeerust
# Processing Record 32 of Set 2 | angicos
# Processing Record 33 of Set 2 | victoria
# Processing Record 34 of Set 2 | sunrise manor
# Processing Record 35 of Set 2 | chuy
# Processing Record 36 of Set 2 | kimbe
# Processing Record 37 of Set 2 | kazalinsk
# City not found. Skipping...
# Processing Record 38 of Set 2 | semme
# Processing Record 39 of Set 2 | whyalla
# Processing Record 40 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 41 of Set 2 | hobart
# Processing Record 42 of Set 2 | manggar
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | henties bay
# Processing Record 45 of Set 2 | pacific grove
# Processing Record 46 of Set 2 | northam
# Processing Record 47 of Set 2 | tete
# Processing Record 48 of Set 2 | stonewall
# Processing Record 49 of Set 2 | vuktyl
# Processing Record 0 of Set 3 | beringovskiy
# Processing Record 1 of Set 3 | miraflores
# Processing Record 2 of Set 3 | bethel
# Processing Record 3 of Set 3 | eureka
# Processing Record 4 of Set 3 | airai
# Processing Record 5 of Set 3 | butaritari
# Processing Record 6 of Set 3 | louisbourg
# City not found. Skipping...
# Processing Record 7 of Set 3 | shubarshi
# Processing Record 8 of Set 3 | dinar
# Processing Record 9 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 3 | aketi
# Processing Record 11 of Set 3 | san luis
# Processing Record 12 of Set 3 | lazarev
# Processing Record 13 of Set 3 | padang
# Processing Record 14 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 15 of Set 3 | narasannapeta
# Processing Record 16 of Set 3 | faanui
# Processing Record 17 of Set 3 | georgetown
# Processing Record 18 of Set 3 | tiarei
# Processing Record 19 of Set 3 | arman
# Processing Record 20 of Set 3 | esmeralda
# Processing Record 21 of Set 3 | opuwo
# Processing Record 22 of Set 3 | oga
# Processing Record 23 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 3 | bambous virieux
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | ahipara
# Processing Record 27 of Set 3 | andenes
# City not found. Skipping...
# Processing Record 28 of Set 3 | hualmay
# Processing Record 29 of Set 3 | ambilobe
# Processing Record 30 of Set 3 | cherskiy
# Processing Record 31 of Set 3 | zeya
# Processing Record 32 of Set 3 | nanortalik
# Processing Record 33 of Set 3 | atar
# Processing Record 34 of Set 3 | guilin
# Processing Record 35 of Set 3 | sedelnikovo
# City not found. Skipping...
# Processing Record 36 of Set 3 | oktyabrskiy
# Processing Record 37 of Set 3 | butia
# Processing Record 38 of Set 3 | sibolga
# Processing Record 39 of Set 3 | mehran
# Processing Record 40 of Set 3 | husavik
# Processing Record 41 of Set 3 | pointe-noire
# Processing Record 42 of Set 3 | bengkulu
# City not found. Skipping...
# Processing Record 43 of Set 3 | kashi
# City not found. Skipping...
# Processing Record 44 of Set 3 | marawi
# Processing Record 45 of Set 3 | maceio
# Processing Record 46 of Set 3 | ivangorod
# Processing Record 47 of Set 3 | mahebourg
# Processing Record 48 of Set 3 | svetlogorsk
# Processing Record 49 of Set 3 | sola
# Processing Record 0 of Set 4 | karaton
# Processing Record 1 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 4 | opunake
# Processing Record 3 of Set 4 | abha
# Processing Record 4 of Set 4 | esperance
# Processing Record 5 of Set 4 | ikalamavony
# Processing Record 6 of Set 4 | new norfolk
# Processing Record 7 of Set 4 | nabire
# Processing Record 8 of Set 4 | vardo
# Processing Record 9 of Set 4 | east london
# Processing Record 10 of Set 4 | aswan
# Processing Record 11 of Set 4 | ferrol
# Processing Record 12 of Set 4 | constitucion
# Processing Record 13 of Set 4 | tessalit
# Processing Record 14 of Set 4 | taunggyi
# Processing Record 15 of Set 4 | redmond
# Processing Record 16 of Set 4 | gumdag
# Processing Record 17 of Set 4 | guerrero negro
# Processing Record 18 of Set 4 | berdyuzhye
# City not found. Skipping...
# Processing Record 19 of Set 4 | belaya gora
# Processing Record 20 of Set 4 | santa cruz
# Processing Record 21 of Set 4 | chapais
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | powell
# Processing Record 24 of Set 4 | dunedin
# Processing Record 25 of Set 4 | ilulissat
# Processing Record 26 of Set 4 | coahuayana
# Processing Record 27 of Set 4 | kisangani
# Processing Record 28 of Set 4 | qaanaaq
# Processing Record 29 of Set 4 | kahului
# Processing Record 30 of Set 4 | bocana de paiwas
# Processing Record 31 of Set 4 | turtas
# Processing Record 32 of Set 4 | saint-pierre
# Processing Record 33 of Set 4 | tuktoyaktuk
# Processing Record 34 of Set 4 | uglegorsk
# Processing Record 35 of Set 4 | barrow
# Processing Record 36 of Set 4 | tual
# Processing Record 37 of Set 4 | shahrud
# Processing Record 38 of Set 4 | namibe
# Processing Record 39 of Set 4 | tazovskiy
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | ketchenery
# City not found. Skipping...
# Processing Record 42 of Set 4 | watsa
# Processing Record 43 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 44 of Set 4 | longyearbyen
# Processing Record 45 of Set 4 | mao
# Processing Record 46 of Set 4 | pevek
# Processing Record 47 of Set 4 | hobyo
# Processing Record 48 of Set 4 | mayor pablo lagerenza
# Processing Record 49 of Set 4 | palu
# Processing Record 0 of Set 5 | honningsvag
# Processing Record 1 of Set 5 | gunjur
# Processing Record 2 of Set 5 | port arthur
# Processing Record 3 of Set 5 | cockburn harbour
# City not found. Skipping...
# Processing Record 4 of Set 5 | maningrida
# Processing Record 5 of Set 5 | hihifo
# City not found. Skipping...
# Processing Record 6 of Set 5 | imbituba
# Processing Record 7 of Set 5 | quimper
# Processing Record 8 of Set 5 | guliston
# Processing Record 9 of Set 5 | sur
# Processing Record 10 of Set 5 | torbay
# Processing Record 11 of Set 5 | norman wells
# Processing Record 12 of Set 5 | khash
# Processing Record 13 of Set 5 | odesskoye
# Processing Record 14 of Set 5 | tera
# Processing Record 15 of Set 5 | fort nelson
# Processing Record 16 of Set 5 | biak
# Processing Record 17 of Set 5 | iracoubo
# Processing Record 18 of Set 5 | oranjestad
# Processing Record 19 of Set 5 | mazyr
# Processing Record 20 of Set 5 | chepareria
# Processing Record 21 of Set 5 | zhezkazgan
# Processing Record 22 of Set 5 | tolstoy-yurt
# Processing Record 23 of Set 5 | bathsheba
# Processing Record 24 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 5 | mumford
# Processing Record 26 of Set 5 | sorong
# Processing Record 27 of Set 5 | khovu-aksy
# Processing Record 28 of Set 5 | tecoanapa
# Processing Record 29 of Set 5 | chivilcoy
# Processing Record 30 of Set 5 | rawah
# City not found. Skipping...
# Processing Record 31 of Set 5 | pimentel
# Processing Record 32 of Set 5 | tres arroyos
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | burica
# City not found. Skipping...
# Processing Record 35 of Set 5 | san cristobal
# Processing Record 36 of Set 5 | astorga
# Processing Record 37 of Set 5 | tapaua
# City not found. Skipping...
# Processing Record 38 of Set 5 | sinor
# Processing Record 39 of Set 5 | sakakah
# City not found. Skipping...
# Processing Record 40 of Set 5 | shenjiamen
# Processing Record 41 of Set 5 | necochea
# Processing Record 42 of Set 5 | rio grande
# Processing Record 43 of Set 5 | challans
# Processing Record 44 of Set 5 | cockburn town
# Processing Record 45 of Set 5 | chokurdakh
# Processing Record 46 of Set 5 | broome
# Processing Record 47 of Set 5 | mareeba
# Processing Record 48 of Set 5 | mikhaylovka
# Processing Record 49 of Set 5 | acari
# Processing Record 0 of Set 6 | igarka
# Processing Record 1 of Set 6 | srednekolymsk
# Processing Record 2 of Set 6 | port hardy
# Processing Record 3 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 4 of Set 6 | jishou
# Processing Record 5 of Set 6 | luderitz
# Processing Record 6 of Set 6 | moose factory
# Processing Record 7 of Set 6 | tura
# Processing Record 8 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 9 of Set 6 | mayumba
# Processing Record 10 of Set 6 | baoqing
# Processing Record 11 of Set 6 | san juan
# Processing Record 12 of Set 6 | sotnikovskoye
# Processing Record 13 of Set 6 | perevolotskiy
# Processing Record 14 of Set 6 | raudeberg
# Processing Record 15 of Set 6 | tabialan
# City not found. Skipping...
# Processing Record 16 of Set 6 | diamantino
# Processing Record 17 of Set 6 | tougue
# Processing Record 18 of Set 6 | catamarca
# City not found. Skipping...
# Processing Record 19 of Set 6 | ceres
# Processing Record 20 of Set 6 | farafangana
# Processing Record 21 of Set 6 | marang
# City not found. Skipping...
# Processing Record 22 of Set 6 | camacha
# Processing Record 23 of Set 6 | nishihara
# Processing Record 24 of Set 6 | bam
# Processing Record 25 of Set 6 | kuusamo
# Processing Record 26 of Set 6 | kroderen
# City not found. Skipping...
# Processing Record 27 of Set 6 | alvorada
# Processing Record 28 of Set 6 | linchuan
# City not found. Skipping...
# Processing Record 29 of Set 6 | narsaq
# Processing Record 30 of Set 6 | iskateley
# Processing Record 31 of Set 6 | nakamura
# Processing Record 32 of Set 6 | awbari
# Processing Record 33 of Set 6 | ust-maya
# Processing Record 34 of Set 6 | jangaon
# Processing Record 35 of Set 6 | kenai
# Processing Record 36 of Set 6 | udayagiri
# Processing Record 37 of Set 6 | guekedou
# City not found. Skipping...
# Processing Record 38 of Set 6 | mount isa
# Processing Record 39 of Set 6 | zarate
# Processing Record 40 of Set 6 | bose
# Processing Record 41 of Set 6 | phuthaditjhaba
# Processing Record 42 of Set 6 | kailua
# Processing Record 43 of Set 6 | walvis bay
# Processing Record 44 of Set 6 | geraldton
# Processing Record 45 of Set 6 | hamilton
# Processing Record 46 of Set 6 | mount gambier
# Processing Record 47 of Set 6 | alofi
# Processing Record 48 of Set 6 | goderich
# Processing Record 49 of Set 6 | galle
# Processing Record 0 of Set 7 | lulea
# Processing Record 1 of Set 7 | sao filipe
# Processing Record 2 of Set 7 | kandi
# Processing Record 3 of Set 7 | jiuquan
# Processing Record 4 of Set 7 | mount vernon
# Processing Record 5 of Set 7 | dumas
# Processing Record 6 of Set 7 | saint-joseph
# Processing Record 7 of Set 7 | papara
# Processing Record 8 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 9 of Set 7 | avera
# Processing Record 10 of Set 7 | kautokeino
# Processing Record 11 of Set 7 | riyadh
# Processing Record 12 of Set 7 | viedma
# Processing Record 13 of Set 7 | jian
# Processing Record 14 of Set 7 | araouane
# Processing Record 15 of Set 7 | obukhiv
# Processing Record 16 of Set 7 | krasnoselkup
# City not found. Skipping...
# Processing Record 17 of Set 7 | finnsnes
# Processing Record 18 of Set 7 | urmary
# Processing Record 19 of Set 7 | lakes entrance
# Processing Record 20 of Set 7 | velingrad
# Processing Record 21 of Set 7 | kanye
# Processing Record 22 of Set 7 | harper
# Processing Record 23 of Set 7 | barahona
# Processing Record 24 of Set 7 | puerto narino
# Processing Record 25 of Set 7 | preobrazheniye
# Processing Record 26 of Set 7 | murwillumbah
# Processing Record 27 of Set 7 | lata
# Processing Record 28 of Set 7 | san jose
# Processing Record 29 of Set 7 | stornoway
# City not found. Skipping...
# Processing Record 30 of Set 7 | syamzha
# Processing Record 31 of Set 7 | moussoro
# Processing Record 32 of Set 7 | urumqi
# City not found. Skipping...
# Processing Record 33 of Set 7 | leh
# Processing Record 34 of Set 7 | whitehorse
# Processing Record 35 of Set 7 | sabang
# Processing Record 36 of Set 7 | upington
# Processing Record 37 of Set 7 | hashtrud
# Processing Record 38 of Set 7 | ouesso
# Processing Record 39 of Set 7 | port-gentil
# Processing Record 40 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 7 | lebu
# Processing Record 42 of Set 7 | sinnamary
# Processing Record 43 of Set 7 | fereydun kenar
# Processing Record 44 of Set 7 | touros
# Processing Record 45 of Set 7 | inirida
# Processing Record 46 of Set 7 | saint-augustin
# Processing Record 47 of Set 7 | camopi
# Processing Record 48 of Set 7 | san patricio
# Processing Record 49 of Set 7 | clyde river
# Processing Record 0 of Set 8 | diu
# Processing Record 1 of Set 8 | jahanabad
# Processing Record 2 of Set 8 | ugoofaaru
# Processing Record 3 of Set 8 | stantsionno-oyashinskiy
# Processing Record 4 of Set 8 | san quintin
# Processing Record 5 of Set 8 | nemuro
# Processing Record 6 of Set 8 | marsh harbour
# Processing Record 7 of Set 8 | copiapo
# Processing Record 8 of Set 8 | sakaiminato
# Processing Record 9 of Set 8 | dauriya
# Processing Record 10 of Set 8 | takoradi
# Processing Record 11 of Set 8 | port keats
# Processing Record 12 of Set 8 | iqaluit
# Processing Record 13 of Set 8 | kruisfontein
# Processing Record 14 of Set 8 | curup
# Processing Record 15 of Set 8 | hilo
# Processing Record 16 of Set 8 | fukue
# Processing Record 17 of Set 8 | telford
# Processing Record 18 of Set 8 | ippy
# Processing Record 19 of Set 8 | aloleng
# Processing Record 20 of Set 8 | lorengau
# Processing Record 21 of Set 8 | paris
# Processing Record 22 of Set 8 | olafsvik
# City not found. Skipping...
# Processing Record 23 of Set 8 | hasaki
# Processing Record 24 of Set 8 | sisimiut
# Processing Record 25 of Set 8 | bull savanna
# Processing Record 26 of Set 8 | ridgecrest
# Processing Record 27 of Set 8 | dzhusaly
# City not found. Skipping...
# Processing Record 28 of Set 8 | elko
# Processing Record 29 of Set 8 | khor
# Processing Record 30 of Set 8 | gisborne
# Processing Record 31 of Set 8 | mackay
# Processing Record 32 of Set 8 | maltahohe
# Processing Record 33 of Set 8 | mananjary
# Processing Record 34 of Set 8 | olinda
# Processing Record 35 of Set 8 | poum
# Processing Record 36 of Set 8 | kihei
# Processing Record 37 of Set 8 | sambava
# Processing Record 38 of Set 8 | nuuk
# Processing Record 39 of Set 8 | riyaq
# City not found. Skipping...
# Processing Record 40 of Set 8 | huarmey
# Processing Record 41 of Set 8 | san ramon de la nueva oran
# Processing Record 42 of Set 8 | puerto leguizamo
# Processing Record 43 of Set 8 | honiara
# Processing Record 44 of Set 8 | leshukonskoye
# Processing Record 45 of Set 8 | talara
# Processing Record 46 of Set 8 | jiayuguan
# Processing Record 47 of Set 8 | nome
# Processing Record 48 of Set 8 | kupang
# Processing Record 49 of Set 8 | puri
# Processing Record 0 of Set 9 | rio de jesus
# Processing Record 1 of Set 9 | gopalpur
# Processing Record 2 of Set 9 | monrovia
# Processing Record 3 of Set 9 | harbour breton
# Processing Record 4 of Set 9 | haines junction
# Processing Record 5 of Set 9 | varca
# Processing Record 6 of Set 9 | halalo
# City not found. Skipping...
# Processing Record 7 of Set 9 | taltal
# Processing Record 8 of Set 9 | vila
# Processing Record 9 of Set 9 | matay
# Processing Record 10 of Set 9 | brae
# Processing Record 11 of Set 9 | balikpapan
# Processing Record 12 of Set 9 | saint petersburg
# Processing Record 13 of Set 9 | nantucket
# Processing Record 14 of Set 9 | talaya
# Processing Record 15 of Set 9 | vissenbjerg
# Processing Record 16 of Set 9 | omsukchan
# Processing Record 17 of Set 9 | wanaka
# Processing Record 18 of Set 9 | codrington
# Processing Record 19 of Set 9 | daru
# Processing Record 20 of Set 9 | saint anthony
# Processing Record 21 of Set 9 | wencheng
# Processing Record 22 of Set 9 | mount pleasant
# Processing Record 23 of Set 9 | nur
# Processing Record 24 of Set 9 | aracruz
# Processing Record 25 of Set 9 | boa vista
# Processing Record 26 of Set 9 | waddan
# Processing Record 27 of Set 9 | atherton
# Processing Record 28 of Set 9 | umm lajj
# Processing Record 29 of Set 9 | verkhoyansk
# Processing Record 30 of Set 9 | belyy yar
# Processing Record 31 of Set 9 | acaponeta
# Processing Record 32 of Set 9 | san antonio
# Processing Record 33 of Set 9 | mata
# Processing Record 34 of Set 9 | voh
# Processing Record 35 of Set 9 | muros
# Processing Record 36 of Set 9 | christchurch
# Processing Record 37 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 38 of Set 9 | kodinsk
# Processing Record 39 of Set 9 | dymer
# Processing Record 40 of Set 9 | arlit
# Processing Record 41 of Set 9 | sorland
# Processing Record 42 of Set 9 | mayo
# Processing Record 43 of Set 9 | berlevag
# Processing Record 44 of Set 9 | le pradet
# Processing Record 45 of Set 9 | pangody
# Processing Record 46 of Set 9 | bonga
# Processing Record 47 of Set 9 | salalah
# Processing Record 48 of Set 9 | syedove
# Processing Record 49 of Set 9 | auki
# Processing Record 0 of Set 10 | stokmarknes
# Processing Record 1 of Set 10 | zhangjiakou
# Processing Record 2 of Set 10 | laiyang
# Processing Record 3 of Set 10 | bara
# Processing Record 4 of Set 10 | victoria point
# Processing Record 5 of Set 10 | havelock
# Processing Record 6 of Set 10 | turukhansk
# Processing Record 7 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 10 | solsvik
# City not found. Skipping...
# Processing Record 9 of Set 10 | konstantinovka
# Processing Record 10 of Set 10 | pangai
# Processing Record 11 of Set 10 | mokhotlong
# Processing Record 12 of Set 10 | ormara
# Processing Record 13 of Set 10 | yining
# Processing Record 14 of Set 10 | salamanca
# Processing Record 15 of Set 10 | asekeyevo
# Processing Record 16 of Set 10 | grand-santi
# Processing Record 17 of Set 10 | havre-saint-pierre
# Processing Record 18 of Set 10 | oranjemund
# Processing Record 19 of Set 10 | celle
# Processing Record 20 of Set 10 | adrar
# Processing Record 21 of Set 10 | calabozo
# Processing Record 22 of Set 10 | mahibadhoo
# Processing Record 23 of Set 10 | tuatapere
# Processing Record 24 of Set 10 | sechura
# Processing Record 25 of Set 10 | careiro da varzea
# Processing Record 26 of Set 10 | ossora
# Processing Record 27 of Set 10 | japura
# Processing Record 28 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 29 of Set 10 | la libertad
# Processing Record 30 of Set 10 | tazmalt
# Processing Record 31 of Set 10 | jambi
# Processing Record 32 of Set 10 | jega
# Processing Record 33 of Set 10 | olovyannaya
# Processing Record 34 of Set 10 | ostrovnoy
# Processing Record 35 of Set 10 | aguada de pasajeros
# Processing Record 36 of Set 10 | rossosh
# Processing Record 37 of Set 10 | garden city
# Processing Record 38 of Set 10 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 10 | atasu
# Processing Record 40 of Set 10 | banda aceh
# Processing Record 41 of Set 10 | koutiala
# Processing Record 42 of Set 10 | severnoye
# Processing Record 43 of Set 10 | vorukh
# Processing Record 44 of Set 10 | abnub
# Processing Record 45 of Set 10 | sabha
# Processing Record 46 of Set 10 | neuquen
# Processing Record 47 of Set 10 | hendaye
# Processing Record 48 of Set 10 | kahta
# Processing Record 49 of Set 10 | halifax
# Processing Record 0 of Set 11 | tpig
# Processing Record 1 of Set 11 | jacareacanga
# Processing Record 2 of Set 11 | vila franca do campo
# Processing Record 3 of Set 11 | marzuq
# Processing Record 4 of Set 11 | shulan
# Processing Record 5 of Set 11 | la ronge
# Processing Record 6 of Set 11 | tikrit
# Processing Record 7 of Set 11 | dubrovytsya
# Processing Record 8 of Set 11 | pochutla
# Processing Record 9 of Set 11 | antofagasta
# Processing Record 10 of Set 11 | ninghai
# Processing Record 11 of Set 11 | payo
# Processing Record 12 of Set 11 | biskamzha
# Processing Record 13 of Set 11 | ginda
# Processing Record 14 of Set 11 | alekseyevka
# Processing Record 15 of Set 11 | kerzhenets
# City not found. Skipping...
# Processing Record 16 of Set 11 | ampanihy
# Processing Record 17 of Set 11 | arklow
# Processing Record 18 of Set 11 | klaksvik
# Processing Record 19 of Set 11 | loiza
# Processing Record 20 of Set 11 | teeli
# Processing Record 21 of Set 11 | wajima
# Processing Record 22 of Set 11 | gulshat
# City not found. Skipping...
# Processing Record 23 of Set 11 | los llanos de aridane
# Processing Record 24 of Set 11 | lufilufi
# Processing Record 25 of Set 11 | serebryanyy bor
# Processing Record 26 of Set 11 | cabo san lucas
# Processing Record 27 of Set 11 | saldanha
# Processing Record 28 of Set 11 | najran
# Processing Record 29 of Set 11 | san benedetto del tronto
# Processing Record 30 of Set 11 | mezotur
# Processing Record 31 of Set 11 | glubczyce
# Processing Record 32 of Set 11 | carutapera
# Processing Record 33 of Set 11 | bangkalan
# Processing Record 34 of Set 11 | meulaboh
# Processing Record 35 of Set 11 | dera bugti
# Processing Record 36 of Set 11 | pangnirtung
# Processing Record 37 of Set 11 | oriximina
# Processing Record 38 of Set 11 | inongo
# Processing Record 39 of Set 11 | plotnikovo
# Processing Record 40 of Set 11 | rundu
# Processing Record 41 of Set 11 | boshnyakovo
# Processing Record 42 of Set 11 | qui nhon
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#creating dictionary and dataFrame
weather_dict = {
    "City": city_names,
    "Cloudiness": cloudiness,
    "Country": countries,
    "Date": dates,
    "Humidity": humidity,
    "Lat": lats,
    "Lng": lngs,
    "Max Temp": max_temp,
    "Wind Speed": speed
}

weather_data = pd.DataFrame(weather_dict)
weather_data.to_csv(output_data_file, sep=',', encoding="utf-8")
weather_data.count()
# Out:
# City          535
# Cloudiness    535
# Country       535
# Date          535
# Humidity      535
# Lat           535
# Lng           535
# Max Temp      535
# Wind Speed    535
# dtype: int64

# %%
weather_data.head(10)
# Out:
#            City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0      Karratha           0      AU  1547964988        25 -20.74  116.85
# 1        Halden          88      SE  1547963400        92  59.12   11.39
# 2     Jamestown           0      AU  1547964927        82 -33.21  138.60
# 3      Ilhabela           0      BR  1547965023        97 -23.78  -45.36
# 4        Castro           0      CL  1547960400       100 -42.48  -73.76
# 5  Punta Arenas          20      CL  1547964000        61 -53.16  -70.91
# 6         Wewak          92      PG  1547965023        95  -3.55  143.63
# 7  Port Augusta           0      AU  1547964000        40 -32.49  137.76
# 8        Rodino          56      RU  1547965246        93  52.50   80.20
# 9        Dingle          92      PH  1547965004        98  11.00  122.67
#
#    Max Temp  Wind Speed
# 0     40.89        4.26
# 1     -5.00        2.10
# 2     25.19        2.41
# 3     27.54        3.46
# 4     11.00        1.50
# 5      8.00        6.20
# 6     26.04        0.86
# 7     30.00        7.70
# 8     -3.01        5.61
# 9     23.99        5.06

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(lats, max_temp, marker="o", facecolors="lightcoral", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Max Temperature ("+time.strftime("%d/%m/%Y")+")")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")
plt.grid(True)
plt.savefig("output_data/CityLatitudeVsMaxTemperature.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(lats, humidity, marker="o", facecolors="lightcoral", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Humidity ("+time.strftime("%d/%m/%Y")+")")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.savefig("output_data/CityLatitudeVsHumidity.png")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(lats, cloudiness, marker="o", facecolors="lightcoral", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Cloudiness ("+time.strftime("%d/%m/%Y")+")")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.savefig("output_data/CityLatitudeVsCloudiness.png")
plt.grid(True)
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(lats, speed, marker="o", facecolors="lightcoral", edgecolors="black", alpha=0.75)
plt.title("City Latitude vs. Wind Speed ("+time.strftime("%d/%m/%Y")+")")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")
plt.savefig("output_data/CityLatitudeVsWindSpeed.png")
plt.grid(True)
plt.show()
